# %% [markdown]
# ## Analysing the Wrangled Data
#
# Having consolidated the the data from the Real World dataset from multiple files, and put it into the standard format of the Flare ML models, we can move on to establishing some basic facts about the dataset that we now have.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('C:\\Users\\EoinB\\dev\\data\\Real-World-Data\\Dataset.csv').drop(columns='Unnamed: 0')

df.head()
# Out:
#    minaccelX  maxaccelX  diffaccelX  stdaccelX  varaccelX  skewaccelX  \
# 0   1.760935   0.051475    1.709460   0.541914   0.293671    0.401870
# 1   2.371457  -4.335899    6.707356   1.803869   3.253945   -0.156026
# 2  -1.304241  -5.471349    4.167108   1.175195   1.381083    0.063031
# 3  -2.007538  -3.935469    1.927931   0.366355   0.134216   -0.795274
# 4  -2.021305  -3.708618    1.687314   0.189326   0.035844   -2.213309
#
#    kurtaccelX  minaccelY  maxaccelY  diffaccelY  ...  kurtgyroY  mingyroZ  \
# 0   -1.280642   9.807249   8.069058    1.738191  ...   2.303915  0.492663
# 1   -1.094776   8.090606  -1.835754    9.926360  ...   4.649462  0.470672
# 2   -1.420697   4.051588  -2.403180    6.454768  ...   0.740009  0.589790
# 3    0.728898   3.045425  -1.742380    4.787805  ...   2.890924  0.364687
# 4   13.638184   1.552041   0.410606    1.141436  ...  15.999902  0.258701
#
#    maxgyroZ  diffgyroZ  stdgyroZ  vargyroZ  skewgyroZ  kurtgyroZ    subject  \
# ...

# %%
df['label'].value_counts()
# Out:
# lying       1308
# sitting     1306
# walking     1296
# standing    1245
# running     1118
# Name: label, dtype: int64
